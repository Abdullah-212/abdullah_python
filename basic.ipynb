# %%
'welcome'
# Out:
# 'welcome'

# %% [markdown]
# numbers only

# %%
10
# Out:
# 10

# %%
10+5
# Out:
# 15

# %%
12*3
# Out:
# 36

# %%
'hai'
'welcome python'
# Out:
# 'welcome python'

# %%
a='hai'
b='welcome python'

# %%
a
# Out:
# 'hai'

# %%
b
# Out:
# 'welcome python'

# %%
print(a)
print(b)
# Out:
# hai
# welcome python

# %%
input('enter number')
# Out:
# '10'

# %%
input('enter word')
# Out:
# 'car'

# %%
a=input('ente a value')
b=input('enter b value')

# %%
a
# Out:
# '10'

# %%
b
# Out:
# '20'

# %%
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(a+b)
# Out:
# 1020

# %%
print(a,b)
# Out:
# 10 20

# %%
print('a value is '+a)
# Out:
# a value is 10
